# %%
import pandas as pd
import numpy as np
import re
from typing import Generator, Tuple, List
from IPython.display import clear_output
import time
import math

# %% [markdown]
# # Day 10 A1

# %%
ll = [x for x in open("Day10Input.txt").read().strip().split("\n\n")]

#startPoint = (112,18)

#mat = ll[0].split("\n")



print(ll[0].split("\n")[112][18])

for l in ll[0].split("\n"):
    if("S" in l):
        print(l.index("S"), ll[0].split("\n").index(l))
# Out:
# S
# 18 112
