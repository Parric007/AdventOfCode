# %%
import pandas as pd
import numpy as np
import re
from typing import Generator, Tuple, List
from IPython.display import clear_output

# %%
inputDF = pd.read_csv("Day4Input.txt", sep="|")

#print(inputDF)
def getNumberArray(inputArr):
    return inputArr.split(" ")
def getNumberArrayWin(inputArr):
    return inputArr.split(":")[1].split(" ")

inputDF["einzelGewinn"] = inputDF["Gewinnzahlen"].apply(getNumberArrayWin)
inputDF["einzelZahlen"] = inputDF["Zahlen"].apply(getNumberArray)

#print(inputDF["einzelGewinn"][0])
result = 0
for i in range (len(inputDF)): 
    internalResult = 0
    for j in range (len(inputDF["einzelGewinn"][i])):
        for k in range (len(inputDF["einzelZahlen"][i])):
            if(inputDF["einzelGewinn"][i][j] == inputDF["einzelZahlen"][i][k] and inputDF["einzelZahlen"][i][k] != ""):
                #print(inputDF["einzelGewinn"][i][j], inputDF["einzelZahlen"][i][k])
                if(internalResult == 0):
                    internalResult = 1
                else:
                    internalResult *= 2
    #print(internalResult)
    result += internalResult
print(result)
# Out:
# 18519

# %%
inputDF = pd.read_csv("Day4Input.txt", sep="|")

#print(inputDF)
def getNumberArray(inputArr):
    return inputArr.split(" ")
def getNumberArrayWin(inputArr):
    return inputArr.split(":")[1].split(" ")

inputDF["einzelGewinn"] = inputDF["Gewinnzahlen"].apply(getNumberArrayWin)
inputDF["einzelZahlen"] = inputDF["Zahlen"].apply(getNumberArray)

#print(inputDF["einzelGewinn"])
#print(inputDF["einzelZahlen"])
#print(inputDF)


result = 0
i = 0
while( i < len(inputDF)):
    internalResult = 0
    for j in range (len(inputDF["einzelGewinn"][i])):
        for k in range (len(inputDF["einzelZahlen"][i])):
            if(inputDF["einzelGewinn"][i][j] == inputDF["einzelZahlen"][i][k] and inputDF["einzelZahlen"][i][k] != ""):
                #print(inputDF["einzelGewinn"][i][j], inputDF["einzelZahlen"][i][k])
                internalResult+=1
    #print(internalResult)
    for l in range(1,internalResult+1):
        #print(l)
        inputDF = pd.concat([pd.DataFrame([[0, 0, inputDF["einzelGewinn"][i+l],inputDF["einzelZahlen"][i+l]]], columns=inputDF.columns), inputDF])
    i+=1
print(len(inputDF))


#11787590
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:171, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:208, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# KeyError: 198
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 21
#      19 while( i < len(inputDF)):
#      20     internalResult = 0
# ---> 21     for j in range (len(inputDF["einzelGewinn"][i])):
#      22         for k in range (len(inputDF["einzelZahlen"][i])):
#      23             if(inputDF["einzelGewinn"][i][j] == inputDF["einzelZahlen"][i][k] and inputDF["einzelZahlen"][i][k] != ""):
#      24                 #print(inputDF["einzelGewinn"][i][j], inputDF["einzelZahlen"][i][k])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 198
